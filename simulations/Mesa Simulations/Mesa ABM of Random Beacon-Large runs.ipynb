# %% [markdown]
# # Mesa ABM - Large

# %% [markdown]
# ### Simulation notes and instructions

# %% [markdown]
# Notes:
# * Nodes are created simulataneously using the Mesa SimultaneousActivation scheduler
# * The nodes go through a bootstrap phase based on Antonio's diagram. They can only form groups if they are in the mainloop forked state.
#
# Instructions:
# 1. Change variables
# 2. Click on the restart and run kernel icon for ipython

# %%
import random
import simpy
import datetime
import numpy as np
import pandas as pd
import agent
import model
import matplotlib.pyplot as plt
import simulation_functions as sc

# %% [markdown]
# **Initialize Variables**

# %%
group_size = 100 # Group size
#total_tickets = 500 # total virtual stakers
nodes = 200 # number of nodes
active_group_threshold = 50 # min number of active groups to pick from
signature_threshold = 20  # min number of nodes needed to sign
group_expiry = 10 #number of steps after which a group expires
group_formation_threshold = 30 # min number of nodes needed to create a group
node_failure_percent = 5 # % of times nodes fail and have to reconnect
node_death_percent = 0.1 # of time nodes fail and do not reconnect

# %%
# Pre-processing Staker distributions
# Linear y = m * (x + 1) since indices start from 0
ticket_distribution = np.zeros(nodes) 

for i in range (0, nodes):
    ticket_distribution[i] =  10 * (i + 1) # m = 50 gives max y as 1000 which is 2% of 50000

x = np.linspace(1,nodes,nodes)
plt.subplot(2, 1, 1)
plt.bar(x, ticket_distribution)
plt.title("Virtual Staker Distribution")

cdf_L02=sc.create_cdf(nodes,ticket_distribution)
plt.subplot(2, 1, 2)
plt.bar(x, cdf_L02)
plt.title("Virtual Staker Cumulative Distribution")
# Out:
# Text(0.5, 1.0, 'Virtual Staker Cumulative Distribution')

# %%
beacon_model = model.Beacon_Model(nodes, ticket_distribution, active_group_threshold, group_size, signature_threshold, group_expiry, group_formation_threshold, node_failure_percent, node_death_percent)

# %%
active_group_size = []
for i in range (200):
    beacon_model.step()
    active_group_size.append(len(beacon_model.active_groups))
# Out:
# refreshing active nodes list
# Number of nodes in the forked state = 0
# bootstrapping active groups
# number of active groups = 0
# []
# relay request recieved? = True
#      selecting group at random
#      no active groups available
#      registering new group
#              Not enough nodes to register a group
# refreshing active nodes list
# Number of nodes in the forked state = 102
# bootstrapping active groups
# number of active groups = 50
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>]
# group ID 200status = Activesteps to expiry = 10
# group ID 201status = Activesteps to expiry = 10
# group ID 202status = Activesteps to expiry = 10
# group ID 203status = Activesteps to expiry = 10
# group ID 204status = Activesteps to expiry = 10
# group ID 205status = Activesteps to expiry = 10
# group ID 206status = Activesteps to expiry = 10
# group ID 207status = Activesteps to expiry = 10
# group ID 208status = Activesteps to expiry = 10
# group ID 209status = Activesteps to expiry = 10
# group ID 210status = Activesteps to expiry = 10
# group ID 211status = Activesteps to expiry = 10
# group ID 212status = Activesteps to expiry = 10
# group ID 213status = Activesteps to expiry = 10
# group ID 214status = Activesteps to expiry = 10
# group ID 215status = Activesteps to expiry = 10
# group ID 216status = Activesteps to expiry = 10
# group ID 217status = Activesteps to expiry = 10
# group ID 218status = Activesteps to expiry = 10
# group ID 219status = Activesteps to expiry = 10
# group ID 220status = Activesteps to expiry = 10
# group ID 221status = Activesteps to expiry = 10
# group ID 222status = Activesteps to expiry = 10
# group ID 223status = Activesteps to expiry = 10
# group ID 224status = Activesteps to expiry = 10
# group ID 225status = Activesteps to expiry = 10
# group ID 226status = Activesteps to expiry = 10
# group ID 227status = Activesteps to expiry = 10
# group ID 228status = Activesteps to expiry = 10
# group ID 229status = Activesteps to expiry = 10
# group ID 230status = Activesteps to expiry = 10
# group ID 231status = Activesteps to expiry = 10
# group ID 232status = Activesteps to expiry = 10
# group ID 233status = Activesteps to expiry = 10
# group ID 234status = Activesteps to expiry = 10
# group ID 235status = Activesteps to expiry = 10
# group ID 236status = Activesteps to expiry = 10
# group ID 237status = Activesteps to expiry = 10
# group ID 238status = Activesteps to expiry = 10
# group ID 239status = Activesteps to expiry = 10
# group ID 240status = Activesteps to expiry = 10
# group ID 241status = Activesteps to expiry = 10
# group ID 242status = Activesteps to expiry = 10
# group ID 243status = Activesteps to expiry = 10
# group ID 244status = Activesteps to expiry = 10
# group ID 245status = Activesteps to expiry = 10
# group ID 246status = Activesteps to expiry = 10
# group ID 247status = Activesteps to expiry = 10
# group ID 248status = Activesteps to expiry = 10
# group ID 249status = Activesteps to expiry = 10
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 191
# number of active groups = 50
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>]
# group ID 200status = Activesteps to expiry = 9
# group ID 201status = Activesteps to expiry = 9
# group ID 202status = Activesteps to expiry = 9
# group ID 203status = Activesteps to expiry = 9
# group ID 204status = Activesteps to expiry = 9
# group ID 205status = Activesteps to expiry = 9
# group ID 206status = Activesteps to expiry = 9
# group ID 207status = Activesteps to expiry = 9
# group ID 208status = Activesteps to expiry = 9
# group ID 209status = Activesteps to expiry = 9
# group ID 210status = Activesteps to expiry = 9
# group ID 211status = Activesteps to expiry = 9
# group ID 212status = Activesteps to expiry = 9
# group ID 213status = Activesteps to expiry = 9
# group ID 214status = Activesteps to expiry = 9
# group ID 215status = Activesteps to expiry = 9
# group ID 216status = Activesteps to expiry = 9
# group ID 217status = Activesteps to expiry = 9
# group ID 218status = Activesteps to expiry = 9
# group ID 219status = Activesteps to expiry = 9
# group ID 220status = Activesteps to expiry = 9
# group ID 221status = Activesteps to expiry = 9
# group ID 222status = Activesteps to expiry = 9
# group ID 223status = Activesteps to expiry = 9
# group ID 224status = Activesteps to expiry = 9
# group ID 225status = Activesteps to expiry = 9
# group ID 226status = Activesteps to expiry = 9
# group ID 227status = Activesteps to expiry = 9
# group ID 228status = Activesteps to expiry = 9
# group ID 229status = Activesteps to expiry = 9
# group ID 230status = Activesteps to expiry = 9
# group ID 231status = Activesteps to expiry = 9
# group ID 232status = Activesteps to expiry = 9
# group ID 233status = Activesteps to expiry = 9
# group ID 234status = Activesteps to expiry = 9
# group ID 235status = Activesteps to expiry = 9
# group ID 236status = Activesteps to expiry = 9
# group ID 237status = Activesteps to expiry = 9
# group ID 238status = Activesteps to expiry = 9
# group ID 239status = Activesteps to expiry = 9
# group ID 240status = Activesteps to expiry = 9
# group ID 241status = Activesteps to expiry = 9
# group ID 242status = Activesteps to expiry = 9
# group ID 243status = Activesteps to expiry = 9
# group ID 244status = Activesteps to expiry = 9
# group ID 245status = Activesteps to expiry = 9
# group ID 246status = Activesteps to expiry = 9
# group ID 247status = Activesteps to expiry = 9
# group ID 248status = Activesteps to expiry = 9
# group ID 249status = Activesteps to expiry = 9
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 184
# number of active groups = 50
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>]
# group ID 200status = Activesteps to expiry = 8
# group ID 201status = Activesteps to expiry = 8
# group ID 202status = Activesteps to expiry = 8
# group ID 203status = Activesteps to expiry = 8
# group ID 204status = Activesteps to expiry = 8
# group ID 205status = Activesteps to expiry = 8
# group ID 206status = Activesteps to expiry = 8
# group ID 207status = Activesteps to expiry = 8
# group ID 208status = Activesteps to expiry = 8
# group ID 209status = Activesteps to expiry = 8
# group ID 210status = Activesteps to expiry = 8
# group ID 211status = Activesteps to expiry = 8
# group ID 212status = Activesteps to expiry = 8
# group ID 213status = Activesteps to expiry = 8
# group ID 214status = Activesteps to expiry = 8
# group ID 215status = Activesteps to expiry = 8
# group ID 216status = Activesteps to expiry = 8
# group ID 217status = Activesteps to expiry = 8
# group ID 218status = Activesteps to expiry = 8
# group ID 219status = Activesteps to expiry = 8
# group ID 220status = Activesteps to expiry = 8
# group ID 221status = Activesteps to expiry = 8
# group ID 222status = Activesteps to expiry = 8
# group ID 223status = Activesteps to expiry = 8
# group ID 224status = Activesteps to expiry = 8
# group ID 225status = Activesteps to expiry = 8
# group ID 226status = Activesteps to expiry = 8
# group ID 227status = Activesteps to expiry = 8
# group ID 228status = Activesteps to expiry = 8
# group ID 229status = Activesteps to expiry = 8
# group ID 230status = Activesteps to expiry = 8
# group ID 231status = Activesteps to expiry = 8
# group ID 232status = Activesteps to expiry = 8
# group ID 233status = Activesteps to expiry = 8
# group ID 234status = Activesteps to expiry = 8
# group ID 235status = Activesteps to expiry = 8
# group ID 236status = Activesteps to expiry = 8
# group ID 237status = Activesteps to expiry = 8
# group ID 238status = Activesteps to expiry = 8
# group ID 239status = Activesteps to expiry = 8
# group ID 240status = Activesteps to expiry = 8
# group ID 241status = Activesteps to expiry = 8
# group ID 242status = Activesteps to expiry = 8
# group ID 243status = Activesteps to expiry = 8
# group ID 244status = Activesteps to expiry = 8
# group ID 245status = Activesteps to expiry = 8
# group ID 246status = Activesteps to expiry = 8
# group ID 247status = Activesteps to expiry = 8
# group ID 248status = Activesteps to expiry = 8
# group ID 249status = Activesteps to expiry = 8
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 190
# number of active groups = 50
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>]
# group ID 200status = Activesteps to expiry = 7
# group ID 201status = Activesteps to expiry = 7
# group ID 202status = Activesteps to expiry = 7
# group ID 203status = Activesteps to expiry = 7
# group ID 204status = Activesteps to expiry = 7
# group ID 205status = Activesteps to expiry = 7
# group ID 206status = Activesteps to expiry = 7
# group ID 207status = Activesteps to expiry = 7
# group ID 208status = Activesteps to expiry = 7
# group ID 209status = Activesteps to expiry = 7
# group ID 210status = Activesteps to expiry = 7
# group ID 211status = Activesteps to expiry = 7
# group ID 212status = Activesteps to expiry = 7
# group ID 213status = Activesteps to expiry = 7
# group ID 214status = Activesteps to expiry = 7
# group ID 215status = Activesteps to expiry = 7
# group ID 216status = Activesteps to expiry = 7
# group ID 217status = Activesteps to expiry = 7
# group ID 218status = Activesteps to expiry = 7
# group ID 219status = Activesteps to expiry = 7
# group ID 220status = Activesteps to expiry = 7
# group ID 221status = Activesteps to expiry = 7
# group ID 222status = Activesteps to expiry = 7
# group ID 223status = Activesteps to expiry = 7
# group ID 224status = Activesteps to expiry = 7
# group ID 225status = Activesteps to expiry = 7
# group ID 226status = Activesteps to expiry = 7
# group ID 227status = Activesteps to expiry = 7
# group ID 228status = Activesteps to expiry = 7
# group ID 229status = Activesteps to expiry = 7
# group ID 230status = Activesteps to expiry = 7
# group ID 231status = Activesteps to expiry = 7
# group ID 232status = Activesteps to expiry = 7
# group ID 233status = Activesteps to expiry = 7
# group ID 234status = Activesteps to expiry = 7
# group ID 235status = Activesteps to expiry = 7
# group ID 236status = Activesteps to expiry = 7
# group ID 237status = Activesteps to expiry = 7
# group ID 238status = Activesteps to expiry = 7
# group ID 239status = Activesteps to expiry = 7
# group ID 240status = Activesteps to expiry = 7
# group ID 241status = Activesteps to expiry = 7
# group ID 242status = Activesteps to expiry = 7
# group ID 243status = Activesteps to expiry = 7
# group ID 244status = Activesteps to expiry = 7
# group ID 245status = Activesteps to expiry = 7
# group ID 246status = Activesteps to expiry = 7
# group ID 247status = Activesteps to expiry = 7
# group ID 248status = Activesteps to expiry = 7
# group ID 249status = Activesteps to expiry = 7
# relay request recieved? = True
#      selecting group at random
# Starting signature process:
#      Checking for active nodes in randomly selected group
# 95
#          signature successful
#      registering new group
# refreshing active nodes list
# Number of nodes in the forked state = 191
# number of active groups = 51
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>, <agent.Group object at 0x11980eb70>]
# group ID 200status = Activesteps to expiry = 6
# group ID 201status = Activesteps to expiry = 6
# group ID 202status = Activesteps to expiry = 6
# group ID 203status = Activesteps to expiry = 6
# group ID 204status = Activesteps to expiry = 6
# group ID 205status = Activesteps to expiry = 6
# group ID 206status = Activesteps to expiry = 6
# group ID 207status = Activesteps to expiry = 6
# group ID 208status = Activesteps to expiry = 6
# group ID 209status = Activesteps to expiry = 6
# group ID 210status = Activesteps to expiry = 6
# group ID 211status = Activesteps to expiry = 6
# group ID 212status = Activesteps to expiry = 6
# group ID 213status = Activesteps to expiry = 6
# group ID 214status = Activesteps to expiry = 6
# group ID 215status = Activesteps to expiry = 6
# group ID 216status = Activesteps to expiry = 6
# group ID 217status = Activesteps to expiry = 6
# group ID 218status = Activesteps to expiry = 6
# group ID 219status = Activesteps to expiry = 6
# group ID 220status = Activesteps to expiry = 6
# group ID 221status = Activesteps to expiry = 6
# group ID 222status = Activesteps to expiry = 6
# group ID 223status = Activesteps to expiry = 6
# group ID 224status = Activesteps to expiry = 6
# group ID 225status = Activesteps to expiry = 6
# group ID 226status = Activesteps to expiry = 6
# group ID 227status = Activesteps to expiry = 6
# group ID 228status = Activesteps to expiry = 6
# group ID 229status = Activesteps to expiry = 6
# group ID 230status = Activesteps to expiry = 6
# group ID 231status = Activesteps to expiry = 6
# group ID 232status = Activesteps to expiry = 6
# group ID 233status = Activesteps to expiry = 6
# group ID 234status = Activesteps to expiry = 6
# group ID 235status = Activesteps to expiry = 6
# group ID 236status = Activesteps to expiry = 6
# group ID 237status = Activesteps to expiry = 6
# group ID 238status = Activesteps to expiry = 6
# group ID 239status = Activesteps to expiry = 6
# group ID 240status = Activesteps to expiry = 6
# group ID 241status = Activesteps to expiry = 6
# group ID 242status = Activesteps to expiry = 6
# group ID 243status = Activesteps to expiry = 6
# group ID 244status = Activesteps to expiry = 6
# group ID 245status = Activesteps to expiry = 6
# group ID 246status = Activesteps to expiry = 6
# group ID 247status = Activesteps to expiry = 6
# group ID 248status = Activesteps to expiry = 6
# group ID 249status = Activesteps to expiry = 6
# group ID 250status = Activesteps to expiry = 9
# relay request recieved? = True
#      selecting group at random
# Starting signature process:
#      Checking for active nodes in randomly selected group
# 96
#          signature successful
#      registering new group
# refreshing active nodes list
# Number of nodes in the forked state = 189
# number of active groups = 52
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>, <agent.Group object at 0x11980eb70>, <agent.Group object at 0x117389be0>]
# group ID 200status = Activesteps to expiry = 5
# group ID 201status = Activesteps to expiry = 5
# group ID 202status = Activesteps to expiry = 5
# group ID 203status = Activesteps to expiry = 5
# group ID 204status = Activesteps to expiry = 5
# group ID 205status = Activesteps to expiry = 5
# group ID 206status = Activesteps to expiry = 5
# group ID 207status = Activesteps to expiry = 5
# group ID 208status = Activesteps to expiry = 5
# group ID 209status = Activesteps to expiry = 5
# group ID 210status = Activesteps to expiry = 5
# group ID 211status = Activesteps to expiry = 5
# group ID 212status = Activesteps to expiry = 5
# group ID 213status = Activesteps to expiry = 5
# group ID 214status = Activesteps to expiry = 5
# group ID 215status = Activesteps to expiry = 5
# group ID 216status = Activesteps to expiry = 5
# group ID 217status = Activesteps to expiry = 5
# group ID 218status = Activesteps to expiry = 5
# group ID 219status = Activesteps to expiry = 5
# group ID 220status = Activesteps to expiry = 5
# group ID 221status = Activesteps to expiry = 5
# group ID 222status = Activesteps to expiry = 5
# group ID 223status = Activesteps to expiry = 5
# group ID 224status = Activesteps to expiry = 5
# group ID 225status = Activesteps to expiry = 5
# group ID 226status = Activesteps to expiry = 5
# group ID 227status = Activesteps to expiry = 5
# group ID 228status = Activesteps to expiry = 5
# group ID 229status = Activesteps to expiry = 5
# group ID 230status = Activesteps to expiry = 5
# group ID 231status = Activesteps to expiry = 5
# group ID 232status = Activesteps to expiry = 5
# group ID 233status = Activesteps to expiry = 5
# group ID 234status = Activesteps to expiry = 5
# group ID 235status = Activesteps to expiry = 5
# group ID 236status = Activesteps to expiry = 5
# group ID 237status = Activesteps to expiry = 5
# group ID 238status = Activesteps to expiry = 5
# group ID 239status = Activesteps to expiry = 5
# group ID 240status = Activesteps to expiry = 5
# group ID 241status = Activesteps to expiry = 5
# group ID 242status = Activesteps to expiry = 5
# group ID 243status = Activesteps to expiry = 5
# group ID 244status = Activesteps to expiry = 5
# group ID 245status = Activesteps to expiry = 5
# group ID 246status = Activesteps to expiry = 5
# group ID 247status = Activesteps to expiry = 5
# group ID 248status = Activesteps to expiry = 5
# group ID 249status = Activesteps to expiry = 5
# group ID 250status = Activesteps to expiry = 8
# group ID 251status = Activesteps to expiry = 9
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 187
# number of active groups = 52
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>, <agent.Group object at 0x11980eb70>, <agent.Group object at 0x117389be0>]
# group ID 200status = Activesteps to expiry = 4
# group ID 201status = Activesteps to expiry = 4
# group ID 202status = Activesteps to expiry = 4
# group ID 203status = Activesteps to expiry = 4
# group ID 204status = Activesteps to expiry = 4
# group ID 205status = Activesteps to expiry = 4
# group ID 206status = Activesteps to expiry = 4
# group ID 207status = Activesteps to expiry = 4
# group ID 208status = Activesteps to expiry = 4
# group ID 209status = Activesteps to expiry = 4
# group ID 210status = Activesteps to expiry = 4
# group ID 211status = Activesteps to expiry = 4
# group ID 212status = Activesteps to expiry = 4
# group ID 213status = Activesteps to expiry = 4
# group ID 214status = Activesteps to expiry = 4
# group ID 215status = Activesteps to expiry = 4
# group ID 216status = Activesteps to expiry = 4
# group ID 217status = Activesteps to expiry = 4
# group ID 218status = Activesteps to expiry = 4
# group ID 219status = Activesteps to expiry = 4
# group ID 220status = Activesteps to expiry = 4
# group ID 221status = Activesteps to expiry = 4
# group ID 222status = Activesteps to expiry = 4
# group ID 223status = Activesteps to expiry = 4
# group ID 224status = Activesteps to expiry = 4
# group ID 225status = Activesteps to expiry = 4
# group ID 226status = Activesteps to expiry = 4
# group ID 227status = Activesteps to expiry = 4
# group ID 228status = Activesteps to expiry = 4
# group ID 229status = Activesteps to expiry = 4
# group ID 230status = Activesteps to expiry = 4
# group ID 231status = Activesteps to expiry = 4
# group ID 232status = Activesteps to expiry = 4
# group ID 233status = Activesteps to expiry = 4
# group ID 234status = Activesteps to expiry = 4
# group ID 235status = Activesteps to expiry = 4
# group ID 236status = Activesteps to expiry = 4
# group ID 237status = Activesteps to expiry = 4
# group ID 238status = Activesteps to expiry = 4
# group ID 239status = Activesteps to expiry = 4
# group ID 240status = Activesteps to expiry = 4
# group ID 241status = Activesteps to expiry = 4
# group ID 242status = Activesteps to expiry = 4
# group ID 243status = Activesteps to expiry = 4
# group ID 244status = Activesteps to expiry = 4
# group ID 245status = Activesteps to expiry = 4
# group ID 246status = Activesteps to expiry = 4
# group ID 247status = Activesteps to expiry = 4
# group ID 248status = Activesteps to expiry = 4
# group ID 249status = Activesteps to expiry = 4
# group ID 250status = Activesteps to expiry = 7
# group ID 251status = Activesteps to expiry = 8
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 190
# number of active groups = 52
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>, <agent.Group object at 0x11980eb70>, <agent.Group object at 0x117389be0>]
# group ID 200status = Activesteps to expiry = 3
# group ID 201status = Activesteps to expiry = 3
# group ID 202status = Activesteps to expiry = 3
# group ID 203status = Activesteps to expiry = 3
# group ID 204status = Activesteps to expiry = 3
# group ID 205status = Activesteps to expiry = 3
# group ID 206status = Activesteps to expiry = 3
# group ID 207status = Activesteps to expiry = 3
# group ID 208status = Activesteps to expiry = 3
# group ID 209status = Activesteps to expiry = 3
# group ID 210status = Activesteps to expiry = 3
# group ID 211status = Activesteps to expiry = 3
# group ID 212status = Activesteps to expiry = 3
# group ID 213status = Activesteps to expiry = 3
# group ID 214status = Activesteps to expiry = 3
# group ID 215status = Activesteps to expiry = 3
# group ID 216status = Activesteps to expiry = 3
# group ID 217status = Activesteps to expiry = 3
# group ID 218status = Activesteps to expiry = 3
# group ID 219status = Activesteps to expiry = 3
# group ID 220status = Activesteps to expiry = 3
# group ID 221status = Activesteps to expiry = 3
# group ID 222status = Activesteps to expiry = 3
# group ID 223status = Activesteps to expiry = 3
# group ID 224status = Activesteps to expiry = 3
# group ID 225status = Activesteps to expiry = 3
# group ID 226status = Activesteps to expiry = 3
# group ID 227status = Activesteps to expiry = 3
# group ID 228status = Activesteps to expiry = 3
# group ID 229status = Activesteps to expiry = 3
# group ID 230status = Activesteps to expiry = 3
# group ID 231status = Activesteps to expiry = 3
# group ID 232status = Activesteps to expiry = 3
# group ID 233status = Activesteps to expiry = 3
# group ID 234status = Activesteps to expiry = 3
# group ID 235status = Activesteps to expiry = 3
# group ID 236status = Activesteps to expiry = 3
# group ID 237status = Activesteps to expiry = 3
# group ID 238status = Activesteps to expiry = 3
# group ID 239status = Activesteps to expiry = 3
# group ID 240status = Activesteps to expiry = 3
# group ID 241status = Activesteps to expiry = 3
# group ID 242status = Activesteps to expiry = 3
# group ID 243status = Activesteps to expiry = 3
# group ID 244status = Activesteps to expiry = 3
# group ID 245status = Activesteps to expiry = 3
# group ID 246status = Activesteps to expiry = 3
# group ID 247status = Activesteps to expiry = 3
# group ID 248status = Activesteps to expiry = 3
# group ID 249status = Activesteps to expiry = 3
# group ID 250status = Activesteps to expiry = 6
# group ID 251status = Activesteps to expiry = 7
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 191
# number of active groups = 52
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>, <agent.Group object at 0x11980eb70>, <agent.Group object at 0x117389be0>]
# group ID 200status = Activesteps to expiry = 2
# group ID 201status = Activesteps to expiry = 2
# group ID 202status = Activesteps to expiry = 2
# group ID 203status = Activesteps to expiry = 2
# group ID 204status = Activesteps to expiry = 2
# group ID 205status = Activesteps to expiry = 2
# group ID 206status = Activesteps to expiry = 2
# group ID 207status = Activesteps to expiry = 2
# group ID 208status = Activesteps to expiry = 2
# group ID 209status = Activesteps to expiry = 2
# group ID 210status = Activesteps to expiry = 2
# group ID 211status = Activesteps to expiry = 2
# group ID 212status = Activesteps to expiry = 2
# group ID 213status = Activesteps to expiry = 2
# group ID 214status = Activesteps to expiry = 2
# group ID 215status = Activesteps to expiry = 2
# group ID 216status = Activesteps to expiry = 2
# group ID 217status = Activesteps to expiry = 2
# group ID 218status = Activesteps to expiry = 2
# group ID 219status = Activesteps to expiry = 2
# group ID 220status = Activesteps to expiry = 2
# group ID 221status = Activesteps to expiry = 2
# group ID 222status = Activesteps to expiry = 2
# group ID 223status = Activesteps to expiry = 2
# group ID 224status = Activesteps to expiry = 2
# group ID 225status = Activesteps to expiry = 2
# group ID 226status = Activesteps to expiry = 2
# group ID 227status = Activesteps to expiry = 2
# group ID 228status = Activesteps to expiry = 2
# group ID 229status = Activesteps to expiry = 2
# group ID 230status = Activesteps to expiry = 2
# group ID 231status = Activesteps to expiry = 2
# group ID 232status = Activesteps to expiry = 2
# group ID 233status = Activesteps to expiry = 2
# group ID 234status = Activesteps to expiry = 2
# group ID 235status = Activesteps to expiry = 2
# group ID 236status = Activesteps to expiry = 2
# group ID 237status = Activesteps to expiry = 2
# group ID 238status = Activesteps to expiry = 2
# group ID 239status = Activesteps to expiry = 2
# group ID 240status = Activesteps to expiry = 2
# group ID 241status = Activesteps to expiry = 2
# group ID 242status = Activesteps to expiry = 2
# group ID 243status = Activesteps to expiry = 2
# group ID 244status = Activesteps to expiry = 2
# group ID 245status = Activesteps to expiry = 2
# group ID 246status = Activesteps to expiry = 2
# group ID 247status = Activesteps to expiry = 2
# group ID 248status = Activesteps to expiry = 2
# group ID 249status = Activesteps to expiry = 2
# group ID 250status = Activesteps to expiry = 5
# group ID 251status = Activesteps to expiry = 6
# relay request recieved? = True
#      selecting group at random
# Starting signature process:
#      Checking for active nodes in randomly selected group
# 98
#          signature successful
#      registering new group
# refreshing active nodes list
# Number of nodes in the forked state = 195
# number of active groups = 53
# [<agent.Group object at 0x11980e160>, <agent.Group object at 0x11980e4e0>, <agent.Group object at 0x11980eb00>, <agent.Group object at 0x117389b38>, <agent.Group object at 0x1198441d0>, <agent.Group object at 0x119844128>, <agent.Group object at 0x1198440b8>, <agent.Group object at 0x119844208>, <agent.Group object at 0x119844240>, <agent.Group object at 0x11961e518>, <agent.Group object at 0x11961ef28>, <agent.Group object at 0x11961eac8>, <agent.Group object at 0x11961eeb8>, <agent.Group object at 0x11961eba8>, <agent.Group object at 0x11961e208>, <agent.Group object at 0x11961e198>, <agent.Group object at 0x11961e4e0>, <agent.Group object at 0x11961ee10>, <agent.Group object at 0x11961eb70>, <agent.Group object at 0x11961e438>, <agent.Group object at 0x11961e780>, <agent.Group object at 0x11961e0f0>, <agent.Group object at 0x11961eef0>, <agent.Group object at 0x11961ebe0>, <agent.Group object at 0x11961e1d0>, <agent.Group object at 0x11961e898>, <agent.Group object at 0x11961e860>, <agent.Group object at 0x11961e550>, <agent.Group object at 0x11961e828>, <agent.Group object at 0x119719f98>, <agent.Group object at 0x119719630>, <agent.Group object at 0x119719cc0>, <agent.Group object at 0x119719978>, <agent.Group object at 0x119719908>, <agent.Group object at 0x1197195c0>, <agent.Group object at 0x119719fd0>, <agent.Group object at 0x119719860>, <agent.Group object at 0x119719518>, <agent.Group object at 0x119719940>, <agent.Group object at 0x1197191d0>, <agent.Group object at 0x1197195f8>, <agent.Group object at 0x119719c88>, <agent.Group object at 0x1197192e8>, <agent.Group object at 0x119719c50>, <agent.Group object at 0x119719278>, <agent.Group object at 0x1197192b0>, <agent.Group object at 0x119719ba8>, <agent.Group object at 0x119737e48>, <agent.Group object at 0x119737b70>, <agent.Group object at 0x1197374e0>, <agent.Group object at 0x11980eb70>, <agent.Group object at 0x117389be0>, <agent.Group object at 0x119737eb8>]
# group ID 200status = Activesteps to expiry = 1
# group ID 201status = Activesteps to expiry = 1
# group ID 202status = Activesteps to expiry = 1
# group ID 203status = Activesteps to expiry = 1
# group ID 204status = Activesteps to expiry = 1
# group ID 205status = Activesteps to expiry = 1
# group ID 206status = Activesteps to expiry = 1
# group ID 207status = Activesteps to expiry = 1
# group ID 208status = Activesteps to expiry = 1
# group ID 209status = Activesteps to expiry = 1
# group ID 210status = Activesteps to expiry = 1
# group ID 211status = Activesteps to expiry = 1
# group ID 212status = Activesteps to expiry = 1
# group ID 213status = Activesteps to expiry = 1
# group ID 214status = Activesteps to expiry = 1
# group ID 215status = Activesteps to expiry = 1
# group ID 216status = Activesteps to expiry = 1
# group ID 217status = Activesteps to expiry = 1
# group ID 218status = Activesteps to expiry = 1
# group ID 219status = Activesteps to expiry = 1
# group ID 220status = Activesteps to expiry = 1
# group ID 221status = Activesteps to expiry = 1
# group ID 222status = Activesteps to expiry = 1
# group ID 223status = Activesteps to expiry = 1
# group ID 224status = Activesteps to expiry = 1
# group ID 225status = Activesteps to expiry = 1
# group ID 226status = Activesteps to expiry = 1
# group ID 227status = Activesteps to expiry = 1
# group ID 228status = Activesteps to expiry = 1
# group ID 229status = Activesteps to expiry = 1
# group ID 230status = Activesteps to expiry = 1
# group ID 231status = Activesteps to expiry = 1
# group ID 232status = Activesteps to expiry = 1
# group ID 233status = Activesteps to expiry = 1
# group ID 234status = Activesteps to expiry = 1
# group ID 235status = Activesteps to expiry = 1
# group ID 236status = Activesteps to expiry = 1
# group ID 237status = Activesteps to expiry = 1
# group ID 238status = Activesteps to expiry = 1
# group ID 239status = Activesteps to expiry = 1
# group ID 240status = Activesteps to expiry = 1
# group ID 241status = Activesteps to expiry = 1
# group ID 242status = Activesteps to expiry = 1
# group ID 243status = Activesteps to expiry = 1
# group ID 244status = Activesteps to expiry = 1
# group ID 245status = Activesteps to expiry = 1
# group ID 246status = Activesteps to expiry = 1
# group ID 247status = Activesteps to expiry = 1
# group ID 248status = Activesteps to expiry = 1
# group ID 249status = Activesteps to expiry = 1
# group ID 250status = Activesteps to expiry = 4
# group ID 251status = Activesteps to expiry = 5
# group ID 252status = Activesteps to expiry = 9
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 194
# number of active groups = 3
# [<agent.Group object at 0x11980eb70>, <agent.Group object at 0x117389be0>, <agent.Group object at 0x119737eb8>]
# group ID 200status = Expiredsteps to expiry = 0
# group ID 201status = Expiredsteps to expiry = 0
# group ID 202status = Expiredsteps to expiry = 0
# group ID 203status = Expiredsteps to expiry = 0
# group ID 204status = Expiredsteps to expiry = 0
# group ID 205status = Expiredsteps to expiry = 0
# group ID 206status = Expiredsteps to expiry = 0
# group ID 207status = Expiredsteps to expiry = 0
# group ID 208status = Expiredsteps to expiry = 0
# group ID 209status = Expiredsteps to expiry = 0
# group ID 210status = Expiredsteps to expiry = 0
# group ID 211status = Expiredsteps to expiry = 0
# group ID 212status = Expiredsteps to expiry = 0
# group ID 213status = Expiredsteps to expiry = 0
# group ID 214status = Expiredsteps to expiry = 0
# group ID 215status = Expiredsteps to expiry = 0
# group ID 216status = Expiredsteps to expiry = 0
# group ID 217status = Expiredsteps to expiry = 0
# group ID 218status = Expiredsteps to expiry = 0
# group ID 219status = Expiredsteps to expiry = 0
# group ID 220status = Expiredsteps to expiry = 0
# group ID 221status = Expiredsteps to expiry = 0
# group ID 222status = Expiredsteps to expiry = 0
# group ID 223status = Expiredsteps to expiry = 0
# group ID 224status = Expiredsteps to expiry = 0
# group ID 225status = Expiredsteps to expiry = 0
# group ID 226status = Expiredsteps to expiry = 0
# group ID 227status = Expiredsteps to expiry = 0
# group ID 228status = Expiredsteps to expiry = 0
# group ID 229status = Expiredsteps to expiry = 0
# group ID 230status = Expiredsteps to expiry = 0
# group ID 231status = Expiredsteps to expiry = 0
# group ID 232status = Expiredsteps to expiry = 0
# group ID 233status = Expiredsteps to expiry = 0
# group ID 234status = Expiredsteps to expiry = 0
# group ID 235status = Expiredsteps to expiry = 0
# group ID 236status = Expiredsteps to expiry = 0
# group ID 237status = Expiredsteps to expiry = 0
# group ID 238status = Expiredsteps to expiry = 0
# group ID 239status = Expiredsteps to expiry = 0
# group ID 240status = Expiredsteps to expiry = 0
# group ID 241status = Expiredsteps to expiry = 0
# group ID 242status = Expiredsteps to expiry = 0
# group ID 243status = Expiredsteps to expiry = 0
# group ID 244status = Expiredsteps to expiry = 0
# group ID 245status = Expiredsteps to expiry = 0
# group ID 246status = Expiredsteps to expiry = 0
# group ID 247status = Expiredsteps to expiry = 0
# group ID 248status = Expiredsteps to expiry = 0
# ...
# group ID 329status = Expiredsteps to expiry = -21
# group ID 330status = Expiredsteps to expiry = -20
# group ID 331status = Expiredsteps to expiry = -18
# group ID 332status = Expiredsteps to expiry = -15
# group ID 333status = Expiredsteps to expiry = -10
# group ID 334status = Expiredsteps to expiry = -5
# group ID 335status = Expiredsteps to expiry = -4
# group ID 336status = Expiredsteps to expiry = -3
# group ID 337status = Expiredsteps to expiry = -2
# group ID 338status = Expiredsteps to expiry = 0
# group ID 339status = Activesteps to expiry = 4
# group ID 340status = Activesteps to expiry = 6
# group ID 341status = Activesteps to expiry = 7
# group ID 342status = Activesteps to expiry = 8
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 190
# number of active groups = 4
# [<agent.Group object at 0x11991cb00>, <agent.Group object at 0x11991cb38>, <agent.Group object at 0x11991cba8>, <agent.Group object at 0x11991c978>]
# group ID 200status = Expiredsteps to expiry = -187
# group ID 201status = Expiredsteps to expiry = -187
# group ID 202status = Expiredsteps to expiry = -187
# group ID 203status = Expiredsteps to expiry = -187
# group ID 204status = Expiredsteps to expiry = -187
# group ID 205status = Expiredsteps to expiry = -187
# group ID 206status = Expiredsteps to expiry = -187
# group ID 207status = Expiredsteps to expiry = -187
# group ID 208status = Expiredsteps to expiry = -187
# group ID 209status = Expiredsteps to expiry = -187
# group ID 210status = Expiredsteps to expiry = -187
# group ID 211status = Expiredsteps to expiry = -187
# group ID 212status = Expiredsteps to expiry = -187
# group ID 213status = Expiredsteps to expiry = -187
# group ID 214status = Expiredsteps to expiry = -187
# group ID 215status = Expiredsteps to expiry = -187
# group ID 216status = Expiredsteps to expiry = -187
# group ID 217status = Expiredsteps to expiry = -187
# group ID 218status = Expiredsteps to expiry = -187
# group ID 219status = Expiredsteps to expiry = -187
# group ID 220status = Expiredsteps to expiry = -187
# group ID 221status = Expiredsteps to expiry = -187
# group ID 222status = Expiredsteps to expiry = -187
# group ID 223status = Expiredsteps to expiry = -187
# group ID 224status = Expiredsteps to expiry = -187
# group ID 225status = Expiredsteps to expiry = -187
# group ID 226status = Expiredsteps to expiry = -187
# group ID 227status = Expiredsteps to expiry = -187
# group ID 228status = Expiredsteps to expiry = -187
# group ID 229status = Expiredsteps to expiry = -187
# group ID 230status = Expiredsteps to expiry = -187
# group ID 231status = Expiredsteps to expiry = -187
# group ID 232status = Expiredsteps to expiry = -187
# group ID 233status = Expiredsteps to expiry = -187
# group ID 234status = Expiredsteps to expiry = -187
# group ID 235status = Expiredsteps to expiry = -187
# group ID 236status = Expiredsteps to expiry = -187
# group ID 237status = Expiredsteps to expiry = -187
# group ID 238status = Expiredsteps to expiry = -187
# group ID 239status = Expiredsteps to expiry = -187
# group ID 240status = Expiredsteps to expiry = -187
# group ID 241status = Expiredsteps to expiry = -187
# group ID 242status = Expiredsteps to expiry = -187
# group ID 243status = Expiredsteps to expiry = -187
# group ID 244status = Expiredsteps to expiry = -187
# group ID 245status = Expiredsteps to expiry = -187
# group ID 246status = Expiredsteps to expiry = -187
# group ID 247status = Expiredsteps to expiry = -187
# group ID 248status = Expiredsteps to expiry = -187
# group ID 249status = Expiredsteps to expiry = -187
# group ID 250status = Expiredsteps to expiry = -184
# group ID 251status = Expiredsteps to expiry = -183
# group ID 252status = Expiredsteps to expiry = -179
# group ID 253status = Expiredsteps to expiry = -176
# group ID 254status = Expiredsteps to expiry = -175
# group ID 255status = Expiredsteps to expiry = -174
# group ID 256status = Expiredsteps to expiry = -173
# group ID 257status = Expiredsteps to expiry = -172
# group ID 258status = Expiredsteps to expiry = -168
# group ID 259status = Expiredsteps to expiry = -166
# group ID 260status = Expiredsteps to expiry = -163
# group ID 261status = Expiredsteps to expiry = -161
# group ID 262status = Expiredsteps to expiry = -160
# group ID 263status = Expiredsteps to expiry = -159
# group ID 264status = Expiredsteps to expiry = -158
# group ID 265status = Expiredsteps to expiry = -154
# group ID 266status = Expiredsteps to expiry = -153
# group ID 267status = Expiredsteps to expiry = -152
# group ID 268status = Expiredsteps to expiry = -149
# group ID 269status = Expiredsteps to expiry = -148
# group ID 270status = Expiredsteps to expiry = -147
# group ID 271status = Expiredsteps to expiry = -144
# group ID 272status = Expiredsteps to expiry = -143
# group ID 273status = Expiredsteps to expiry = -141
# group ID 274status = Expiredsteps to expiry = -140
# group ID 275status = Expiredsteps to expiry = -139
# group ID 276status = Expiredsteps to expiry = -138
# group ID 277status = Expiredsteps to expiry = -135
# group ID 278status = Expiredsteps to expiry = -134
# group ID 279status = Expiredsteps to expiry = -133
# group ID 280status = Expiredsteps to expiry = -132
# group ID 281status = Expiredsteps to expiry = -130
# group ID 282status = Expiredsteps to expiry = -129
# group ID 283status = Expiredsteps to expiry = -128
# group ID 284status = Expiredsteps to expiry = -122
# group ID 285status = Expiredsteps to expiry = -121
# group ID 286status = Expiredsteps to expiry = -114
# group ID 287status = Expiredsteps to expiry = -113
# group ID 288status = Expiredsteps to expiry = -112
# group ID 289status = Expiredsteps to expiry = -111
# group ID 290status = Expiredsteps to expiry = -109
# group ID 291status = Expiredsteps to expiry = -108
# group ID 292status = Expiredsteps to expiry = -105
# group ID 293status = Expiredsteps to expiry = -102
# group ID 294status = Expiredsteps to expiry = -101
# group ID 295status = Expiredsteps to expiry = -99
# group ID 296status = Expiredsteps to expiry = -98
# group ID 297status = Expiredsteps to expiry = -91
# group ID 298status = Expiredsteps to expiry = -90
# group ID 299status = Expiredsteps to expiry = -89
# group ID 300status = Expiredsteps to expiry = -88
# group ID 301status = Expiredsteps to expiry = -86
# group ID 302status = Expiredsteps to expiry = -82
# group ID 303status = Expiredsteps to expiry = -79
# group ID 304status = Expiredsteps to expiry = -78
# group ID 305status = Expiredsteps to expiry = -77
# group ID 306status = Expiredsteps to expiry = -76
# group ID 307status = Expiredsteps to expiry = -75
# group ID 308status = Expiredsteps to expiry = -71
# group ID 309status = Expiredsteps to expiry = -68
# group ID 310status = Expiredsteps to expiry = -64
# group ID 311status = Expiredsteps to expiry = -61
# group ID 312status = Expiredsteps to expiry = -59
# group ID 313status = Expiredsteps to expiry = -57
# group ID 314status = Expiredsteps to expiry = -56
# group ID 315status = Expiredsteps to expiry = -55
# group ID 316status = Expiredsteps to expiry = -54
# group ID 317status = Expiredsteps to expiry = -52
# group ID 318status = Expiredsteps to expiry = -49
# group ID 319status = Expiredsteps to expiry = -48
# group ID 320status = Expiredsteps to expiry = -45
# group ID 321status = Expiredsteps to expiry = -43
# group ID 322status = Expiredsteps to expiry = -40
# group ID 323status = Expiredsteps to expiry = -36
# group ID 324status = Expiredsteps to expiry = -35
# group ID 325status = Expiredsteps to expiry = -33
# group ID 326status = Expiredsteps to expiry = -29
# group ID 327status = Expiredsteps to expiry = -26
# group ID 328status = Expiredsteps to expiry = -25
# group ID 329status = Expiredsteps to expiry = -22
# group ID 330status = Expiredsteps to expiry = -21
# group ID 331status = Expiredsteps to expiry = -19
# group ID 332status = Expiredsteps to expiry = -16
# group ID 333status = Expiredsteps to expiry = -11
# group ID 334status = Expiredsteps to expiry = -6
# group ID 335status = Expiredsteps to expiry = -5
# group ID 336status = Expiredsteps to expiry = -4
# group ID 337status = Expiredsteps to expiry = -3
# group ID 338status = Expiredsteps to expiry = -1
# group ID 339status = Activesteps to expiry = 3
# group ID 340status = Activesteps to expiry = 5
# group ID 341status = Activesteps to expiry = 6
# group ID 342status = Activesteps to expiry = 7
# relay request recieved? = False
#      No relay request
# refreshing active nodes list
# Number of nodes in the forked state = 189
# number of active groups = 4
# [<agent.Group object at 0x11991cb00>, <agent.Group object at 0x11991cb38>, <agent.Group object at 0x11991cba8>, <agent.Group object at 0x11991c978>]
# group ID 200status = Expiredsteps to expiry = -188
# group ID 201status = Expiredsteps to expiry = -188
# group ID 202status = Expiredsteps to expiry = -188
# group ID 203status = Expiredsteps to expiry = -188
# group ID 204status = Expiredsteps to expiry = -188
# group ID 205status = Expiredsteps to expiry = -188
# group ID 206status = Expiredsteps to expiry = -188
# group ID 207status = Expiredsteps to expiry = -188
# group ID 208status = Expiredsteps to expiry = -188
# group ID 209status = Expiredsteps to expiry = -188
# group ID 210status = Expiredsteps to expiry = -188
# group ID 211status = Expiredsteps to expiry = -188
# group ID 212status = Expiredsteps to expiry = -188
# group ID 213status = Expiredsteps to expiry = -188
# group ID 214status = Expiredsteps to expiry = -188
# group ID 215status = Expiredsteps to expiry = -188
# group ID 216status = Expiredsteps to expiry = -188
# group ID 217status = Expiredsteps to expiry = -188
# group ID 218status = Expiredsteps to expiry = -188
# group ID 219status = Expiredsteps to expiry = -188
# group ID 220status = Expiredsteps to expiry = -188
# group ID 221status = Expiredsteps to expiry = -188
# group ID 222status = Expiredsteps to expiry = -188
# group ID 223status = Expiredsteps to expiry = -188
# group ID 224status = Expiredsteps to expiry = -188
# group ID 225status = Expiredsteps to expiry = -188
# group ID 226status = Expiredsteps to expiry = -188
# group ID 227status = Expiredsteps to expiry = -188
# group ID 228status = Expiredsteps to expiry = -188
# group ID 229status = Expiredsteps to expiry = -188
# group ID 230status = Expiredsteps to expiry = -188
# group ID 231status = Expiredsteps to expiry = -188
# group ID 232status = Expiredsteps to expiry = -188
# group ID 233status = Expiredsteps to expiry = -188
# group ID 234status = Expiredsteps to expiry = -188
# group ID 235status = Expiredsteps to expiry = -188
# group ID 236status = Expiredsteps to expiry = -188
# group ID 237status = Expiredsteps to expiry = -188
# group ID 238status = Expiredsteps to expiry = -188
# group ID 239status = Expiredsteps to expiry = -188
# group ID 240status = Expiredsteps to expiry = -188
# group ID 241status = Expiredsteps to expiry = -188
# group ID 242status = Expiredsteps to expiry = -188
# group ID 243status = Expiredsteps to expiry = -188
# group ID 244status = Expiredsteps to expiry = -188
# group ID 245status = Expiredsteps to expiry = -188
# group ID 246status = Expiredsteps to expiry = -188
# group ID 247status = Expiredsteps to expiry = -188
# group ID 248status = Expiredsteps to expiry = -188
# group ID 249status = Expiredsteps to expiry = -188
# group ID 250status = Expiredsteps to expiry = -185
# group ID 251status = Expiredsteps to expiry = -184
# group ID 252status = Expiredsteps to expiry = -180
# group ID 253status = Expiredsteps to expiry = -177
# group ID 254status = Expiredsteps to expiry = -176
# group ID 255status = Expiredsteps to expiry = -175
# group ID 256status = Expiredsteps to expiry = -174
# group ID 257status = Expiredsteps to expiry = -173
# group ID 258status = Expiredsteps to expiry = -169
# group ID 259status = Expiredsteps to expiry = -167
# group ID 260status = Expiredsteps to expiry = -164
# group ID 261status = Expiredsteps to expiry = -162
# group ID 262status = Expiredsteps to expiry = -161
# group ID 263status = Expiredsteps to expiry = -160
# group ID 264status = Expiredsteps to expiry = -159
# group ID 265status = Expiredsteps to expiry = -155
# group ID 266status = Expiredsteps to expiry = -154
# group ID 267status = Expiredsteps to expiry = -153
# group ID 268status = Expiredsteps to expiry = -150
# group ID 269status = Expiredsteps to expiry = -149
# group ID 270status = Expiredsteps to expiry = -148
# group ID 271status = Expiredsteps to expiry = -145
# group ID 272status = Expiredsteps to expiry = -144
# group ID 273status = Expiredsteps to expiry = -142
# group ID 274status = Expiredsteps to expiry = -141
# group ID 275status = Expiredsteps to expiry = -140
# group ID 276status = Expiredsteps to expiry = -139
# group ID 277status = Expiredsteps to expiry = -136
# group ID 278status = Expiredsteps to expiry = -135
# group ID 279status = Expiredsteps to expiry = -134
# group ID 280status = Expiredsteps to expiry = -133
# group ID 281status = Expiredsteps to expiry = -131
# group ID 282status = Expiredsteps to expiry = -130
# group ID 283status = Expiredsteps to expiry = -129
# group ID 284status = Expiredsteps to expiry = -123
# group ID 285status = Expiredsteps to expiry = -122
# group ID 286status = Expiredsteps to expiry = -115
# group ID 287status = Expiredsteps to expiry = -114
# group ID 288status = Expiredsteps to expiry = -113
# group ID 289status = Expiredsteps to expiry = -112
# group ID 290status = Expiredsteps to expiry = -110
# group ID 291status = Expiredsteps to expiry = -109
# group ID 292status = Expiredsteps to expiry = -106
# group ID 293status = Expiredsteps to expiry = -103
# group ID 294status = Expiredsteps to expiry = -102
# group ID 295status = Expiredsteps to expiry = -100
# group ID 296status = Expiredsteps to expiry = -99
# group ID 297status = Expiredsteps to expiry = -92
# group ID 298status = Expiredsteps to expiry = -91
# group ID 299status = Expiredsteps to expiry = -90
# group ID 300status = Expiredsteps to expiry = -89
# group ID 301status = Expiredsteps to expiry = -87
# group ID 302status = Expiredsteps to expiry = -83
# group ID 303status = Expiredsteps to expiry = -80
# group ID 304status = Expiredsteps to expiry = -79
# group ID 305status = Expiredsteps to expiry = -78
# group ID 306status = Expiredsteps to expiry = -77
# group ID 307status = Expiredsteps to expiry = -76
# group ID 308status = Expiredsteps to expiry = -72
# group ID 309status = Expiredsteps to expiry = -69
# group ID 310status = Expiredsteps to expiry = -65
# group ID 311status = Expiredsteps to expiry = -62
# group ID 312status = Expiredsteps to expiry = -60
# group ID 313status = Expiredsteps to expiry = -58
# group ID 314status = Expiredsteps to expiry = -57
# group ID 315status = Expiredsteps to expiry = -56
# group ID 316status = Expiredsteps to expiry = -55
# group ID 317status = Expiredsteps to expiry = -53
# group ID 318status = Expiredsteps to expiry = -50
# group ID 319status = Expiredsteps to expiry = -49
# group ID 320status = Expiredsteps to expiry = -46
# group ID 321status = Expiredsteps to expiry = -44
# group ID 322status = Expiredsteps to expiry = -41
# group ID 323status = Expiredsteps to expiry = -37
# group ID 324status = Expiredsteps to expiry = -36
# group ID 325status = Expiredsteps to expiry = -34
# group ID 326status = Expiredsteps to expiry = -30
# group ID 327status = Expiredsteps to expiry = -27
# group ID 328status = Expiredsteps to expiry = -26
# group ID 329status = Expiredsteps to expiry = -23
# group ID 330status = Expiredsteps to expiry = -22
# group ID 331status = Expiredsteps to expiry = -20
# group ID 332status = Expiredsteps to expiry = -17
# group ID 333status = Expiredsteps to expiry = -12
# group ID 334status = Expiredsteps to expiry = -7
# group ID 335status = Expiredsteps to expiry = -6
# group ID 336status = Expiredsteps to expiry = -5
# group ID 337status = Expiredsteps to expiry = -4
# group ID 338status = Expiredsteps to expiry = -2
# group ID 339status = Activesteps to expiry = 2
# group ID 340status = Activesteps to expiry = 4
# group ID 341status = Activesteps to expiry = 5
# group ID 342status = Activesteps to expiry = 6
# relay request recieved? = True
#      selecting group at random
# Starting signature process:
#      Checking for active nodes in randomly selected group
# 98
#          signature successful
#      registering new group

# %%
plt.figure(figsize = (20,5))
plt.hist(active_group_size, bins=range(max(active_group_size)+1))
plt.xticks(np.linspace(1,max(active_group_size),20))
plt.xlabel("group size")
plt.ylabel("frequency")

print(np.median(active_group_size))
# Out:
# 5.0

# %%
plt.figure(figsize = (10,5))
plt.plot(np.linspace(1,len(active_group_size),len(active_group_size)),active_group_size)
plt.xlabel("simulation time")
plt.ylabel("group size")
# Out:
# Text(0, 0.5, 'group size')
