# %%
import random
import simpy
import datetime
import numpy as np

# levers to pull: 
# stake amount and effect on ownership on group; given set group size, 
# failure rates of a single node (explodes!) when it comes bck its subject to connect (use lit)
# what if somebody is attacking the network, cost to bring down system, how much money do they need to get signingrights
# how many availability zones should we distribute this over? group size shrinks over time due to non-profitability


class Node:
    #Node states based on Antonio's diagramming on Feb 15 2019
    #Assume staking mechanism is complete
    def __init__(self, env, identity, start_time, sim_cycles):
        self.env = env
        self.id = identity
        self.starttime = start_time
        self.current_state = "not connected"
        self.process = env.process(self.Connect_Node(env))
        self.relay_request_time = 0
        self.relay_entry_watch_time = 0
        self.ingroup = False
        self.inrelay = False
        self.number_of_entries_generated = 0
        self.number_of_groups_joined = 0
        self.STAKING_AMT = np.random.lognormal(3,1,) #find total tokens from contract
        self.cycle_count = 0
        self.node_status = "online"
        self.max_cycles = sim_cycles


    #Connecting to Ethereum
    def Connect_Node(self, env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        while True:
            ethereum_conection_time = np.random.lognormal(3,1,)
            if ethereum_conection_time>=30:
                #print (str(self.id) + " ethereum connection Failure" + "cycle="+str(self.cycle_count))
                self.current_state = " not connected"
                self.Connect_Node(env)
            else:
                #print (str(self.id) + " ethereum connection success" + " cycle="+str(self.cycle_count))
                env.process(self.Forking_MainLoop(env))               
                self.current_state = " connected"
                yield env.exit()
    
    def Forking_MainLoop(self,env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        #print(str(self.id) + " Forking Main Loop" + " cycle="+str(self.cycle_count))
        env.process(self.Watching_RelayRequest(env))
        env.process(self.Watching_RelayEntry(env))  
        yield env.exit()
    
    # wait for relay request
    def Watching_RelayRequest(self, env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        #print(str(self.id)+" Watching Relay Request" + " cycle="+str(self.cycle_count))
        self.relay_request_time = np.random.normal(3,1,)
        env.process(self.Group_Selection(env))
        yield env.exit()
    
    # watching for relay entry
    def Watching_RelayEntry(self, env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        #print(str(self.id)+" Watching Relay Entry" + " cycle="+str(self.cycle_count))
        self.relay_entry_watch_time = np.random.normal(3,1,)
        yield env.exit()
    
    # Group Selection
    def Group_Selection(self, env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        while True:
            if np.random.randint(10)<5:
                env.process(self.Group_Formation(env))
                yield env.exit()
                
            else:
                print(str(self.id)+" group formation failure" + "cycle="+str(self.cycle_count))
        
    # check if this node is a member of a signing group (assuming this is another process)
    def Group_Member_Check(self, env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        if self.ingroup == True:
            env.process(self.Entry_Generation(env))
            #print (str(self.id)+" in a group" + " cycle="+str(self.cycle_count))
            yield env.exit()
        else:
            #print(str(self.id)+" not a group member" + " cycle="+str(self.cycle_count))
            env.process(self.Watching_RelayEntry(env))
            yield env.exit()
        
    # Generate Entry
    def Entry_Generation(self,env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        #print(str(self.id)+" generated entry" + " cycle="+str(self.cycle_count))
        self.number_of_entries_generated += 1
        self.ingroup = False
        self.cycle_count +=1
        if self. cycle_count > self.max_cycles:
            yield env.exit()
        else:
            env.process(self.Forking_MainLoop(env))
        
    # Form Group
    def Group_Formation(self,env):
        self.node_failure_generator()
        if self.node_status == "failed": yield env.exit()
        #print(str(self.id)+" formed group" + " cycle="+str(self.cycle_count))
        self.ingroup = True
        self.number_of_groups_joined +=1
        env.process(self.Group_Member_Check(env)) #doing it here instead of waiting for relay entry
        env.exit()

    def node_failure_generator(self):
        failure = np.random.lognormal(1,0)
        if failure < 0.5 or failure >1.5 :
            self.node_status = "failed"
        yield self.node_status

# Setup and start the simulation
sim_cycles = 5
TOTAL_TOKEN_AMT = 100

print('Node States')

# Create an environment and start the setup process
env = simpy.Environment()
print("creating nodes")
nodes = [Node(env, 'Node %d' % i, datetime.datetime.now(), sim_cycles)
            for i in range(100)] #number of nodes
env.run()
print("xxxxxxxxxxxxxxxxxxxx")
print(" final node states ")
for n in nodes:
    print(str(n.id) + ", # of Entries = " 
    + str(n.number_of_entries_generated) 
    + ", # Groups Joined = " 
    + str(n.number_of_groups_joined)
    + ", Total relay request time = "
    + str(n.relay_request_time)
    + ", Total relay watch time = "
    + str(n.relay_entry_watch_time)
    + ", Node Status = " + str(n.node_status))
# Out:
# Node States
# creating nodes
# Node 0 group formation failurecycle=0
# Node 0 group formation failurecycle=0
# Node 1 group formation failurecycle=0
# Node 1 group formation failurecycle=0
# Node 1 group formation failurecycle=0
# Node 4 group formation failurecycle=0
# Node 6 group formation failurecycle=0
# Node 6 group formation failurecycle=0
# Node 7 group formation failurecycle=0
# Node 7 group formation failurecycle=0
# Node 11 group formation failurecycle=0
# Node 12 group formation failurecycle=0
# Node 12 group formation failurecycle=0
# Node 13 group formation failurecycle=0
# Node 13 group formation failurecycle=0
# Node 14 group formation failurecycle=0
# Node 14 group formation failurecycle=0
# Node 14 group formation failurecycle=0
# Node 16 group formation failurecycle=0
# Node 16 group formation failurecycle=0
# Node 17 group formation failurecycle=0
# Node 18 group formation failurecycle=0
# Node 24 group formation failurecycle=0
# Node 24 group formation failurecycle=0
# Node 24 group formation failurecycle=0
# Node 25 group formation failurecycle=0
# Node 25 group formation failurecycle=0
# Node 25 group formation failurecycle=0
# Node 28 group formation failurecycle=0
# Node 29 group formation failurecycle=0
# Node 29 group formation failurecycle=0
# Node 29 group formation failurecycle=0
# Node 29 group formation failurecycle=0
# Node 30 group formation failurecycle=0
# Node 31 group formation failurecycle=0
# Node 32 group formation failurecycle=0
# Node 33 group formation failurecycle=0
# Node 33 group formation failurecycle=0
# Node 33 group formation failurecycle=0
# Node 36 group formation failurecycle=0
# Node 37 group formation failurecycle=0
# Node 39 group formation failurecycle=0
# Node 42 group formation failurecycle=0
# Node 42 group formation failurecycle=0
# Node 43 group formation failurecycle=0
# Node 43 group formation failurecycle=0
# Node 43 group formation failurecycle=0
# Node 44 group formation failurecycle=0
# Node 47 group formation failurecycle=0
# Node 49 group formation failurecycle=0
# Node 49 group formation failurecycle=0
# Node 50 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 51 group formation failurecycle=0
# Node 52 group formation failurecycle=0
# Node 52 group formation failurecycle=0
# Node 54 group formation failurecycle=0
# Node 55 group formation failurecycle=0
# Node 55 group formation failurecycle=0
# Node 55 group formation failurecycle=0
# Node 56 group formation failurecycle=0
# Node 57 group formation failurecycle=0
# Node 57 group formation failurecycle=0
# Node 57 group formation failurecycle=0
# Node 57 group formation failurecycle=0
# Node 58 group formation failurecycle=0
# Node 59 group formation failurecycle=0
# Node 59 group formation failurecycle=0
# Node 61 group formation failurecycle=0
# Node 62 group formation failurecycle=0
# Node 62 group formation failurecycle=0
# Node 62 group formation failurecycle=0
# Node 62 group formation failurecycle=0
# Node 63 group formation failurecycle=0
# Node 64 group formation failurecycle=0
# Node 64 group formation failurecycle=0
# Node 64 group formation failurecycle=0
# Node 64 group formation failurecycle=0
# Node 64 group formation failurecycle=0
# Node 66 group formation failurecycle=0
# Node 67 group formation failurecycle=0
# Node 67 group formation failurecycle=0
# Node 67 group formation failurecycle=0
# Node 67 group formation failurecycle=0
# Node 69 group formation failurecycle=0
# Node 69 group formation failurecycle=0
# Node 70 group formation failurecycle=0
# Node 70 group formation failurecycle=0
# Node 70 group formation failurecycle=0
# Node 70 group formation failurecycle=0
# Node 70 group formation failurecycle=0
# Node 70 group formation failurecycle=0
# Node 74 group formation failurecycle=0
# Node 74 group formation failurecycle=0
# Node 74 group formation failurecycle=0
# Node 76 group formation failurecycle=0
# Node 78 group formation failurecycle=0
# Node 78 group formation failurecycle=0
# Node 78 group formation failurecycle=0
# Node 79 group formation failurecycle=0
# Node 79 group formation failurecycle=0
# Node 80 group formation failurecycle=0
# Node 80 group formation failurecycle=0
# Node 80 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 82 group formation failurecycle=0
# Node 83 group formation failurecycle=0
# Node 85 group formation failurecycle=0
# Node 85 group formation failurecycle=0
# Node 85 group formation failurecycle=0
# Node 86 group formation failurecycle=0
# Node 92 group formation failurecycle=0
# Node 93 group formation failurecycle=0
# Node 93 group formation failurecycle=0
# Node 93 group formation failurecycle=0
# Node 93 group formation failurecycle=0
# Node 95 group formation failurecycle=0
# Node 99 group formation failurecycle=0
# Node 99 group formation failurecycle=0
# Node 1 group formation failurecycle=1
# Node 3 group formation failurecycle=1
# Node 3 group formation failurecycle=1
# Node 3 group formation failurecycle=1
# Node 4 group formation failurecycle=1
# Node 4 group formation failurecycle=1
# Node 4 group formation failurecycle=1
# Node 7 group formation failurecycle=1
# Node 11 group formation failurecycle=1
# Node 12 group formation failurecycle=1
# Node 13 group formation failurecycle=1
# Node 13 group formation failurecycle=1
# Node 14 group formation failurecycle=1
# Node 19 group formation failurecycle=1
# Node 21 group formation failurecycle=1
# Node 21 group formation failurecycle=1
# Node 23 group formation failurecycle=1
# Node 30 group formation failurecycle=1
# Node 30 group formation failurecycle=1
# Node 30 group formation failurecycle=1
# Node 30 group formation failurecycle=1
# Node 30 group formation failurecycle=1
# Node 30 group formation failurecycle=1
# Node 30 group formation failurecycle=1
# Node 33 group formation failurecycle=1
# Node 33 group formation failurecycle=1
# Node 33 group formation failurecycle=1
# Node 36 group formation failurecycle=1
# Node 38 group formation failurecycle=1
# Node 38 group formation failurecycle=1
# Node 38 group formation failurecycle=1
# Node 38 group formation failurecycle=1
# Node 39 group formation failurecycle=1
# Node 39 group formation failurecycle=1
# Node 40 group formation failurecycle=1
# Node 40 group formation failurecycle=1
# Node 43 group formation failurecycle=1
# Node 43 group formation failurecycle=1
# Node 43 group formation failurecycle=1
# Node 43 group formation failurecycle=1
# Node 44 group formation failurecycle=1
# Node 44 group formation failurecycle=1
# Node 45 group formation failurecycle=1
# Node 45 group formation failurecycle=1
# Node 47 group formation failurecycle=1
# Node 51 group formation failurecycle=1
# Node 52 group formation failurecycle=1
# Node 57 group formation failurecycle=1
# Node 59 group formation failurecycle=1
# Node 59 group formation failurecycle=1
# Node 59 group formation failurecycle=1
# Node 59 group formation failurecycle=1
# Node 62 group formation failurecycle=1
# Node 66 group formation failurecycle=1
# Node 66 group formation failurecycle=1
# Node 71 group formation failurecycle=1
# Node 72 group formation failurecycle=1
# Node 73 group formation failurecycle=1
# Node 73 group formation failurecycle=1
# Node 75 group formation failurecycle=1
# Node 75 group formation failurecycle=1
# Node 75 group formation failurecycle=1
# Node 75 group formation failurecycle=1
# Node 75 group formation failurecycle=1
# Node 75 group formation failurecycle=1
# Node 76 group formation failurecycle=1
# Node 77 group formation failurecycle=1
# Node 78 group formation failurecycle=1
# Node 78 group formation failurecycle=1
# Node 81 group formation failurecycle=1
# Node 82 group formation failurecycle=1
# Node 84 group formation failurecycle=1
# Node 86 group formation failurecycle=1
# Node 88 group formation failurecycle=1
# Node 88 group formation failurecycle=1
# Node 89 group formation failurecycle=1
# Node 89 group formation failurecycle=1
# Node 91 group formation failurecycle=1
# Node 92 group formation failurecycle=1
# Node 92 group formation failurecycle=1
# Node 92 group formation failurecycle=1
# Node 93 group formation failurecycle=1
# Node 99 group formation failurecycle=1
# Node 99 group formation failurecycle=1
# Node 0 group formation failurecycle=2
# Node 0 group formation failurecycle=2
# Node 2 group formation failurecycle=2
# Node 4 group formation failurecycle=2
# Node 5 group formation failurecycle=2
# Node 5 group formation failurecycle=2
# Node 5 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 7 group formation failurecycle=2
# Node 10 group formation failurecycle=2
# Node 12 group formation failurecycle=2
# Node 12 group formation failurecycle=2
# Node 13 group formation failurecycle=2
# Node 15 group formation failurecycle=2
# Node 16 group formation failurecycle=2
# Node 16 group formation failurecycle=2
# Node 20 group formation failurecycle=2
# Node 20 group formation failurecycle=2
# Node 20 group formation failurecycle=2
# Node 20 group formation failurecycle=2
# Node 20 group formation failurecycle=2
# Node 21 group formation failurecycle=2
# Node 21 group formation failurecycle=2
# Node 23 group formation failurecycle=2
# Node 26 group formation failurecycle=2
# Node 30 group formation failurecycle=2
# Node 33 group formation failurecycle=2
# Node 33 group formation failurecycle=2
# Node 37 group formation failurecycle=2
# Node 37 group formation failurecycle=2
# Node 37 group formation failurecycle=2
# Node 37 group formation failurecycle=2
# Node 41 group formation failurecycle=2
# Node 41 group formation failurecycle=2
# Node 41 group formation failurecycle=2
# Node 42 group formation failurecycle=2
# Node 42 group formation failurecycle=2
# Node 42 group formation failurecycle=2
# Node 43 group formation failurecycle=2
# Node 47 group formation failurecycle=2
# Node 47 group formation failurecycle=2
# Node 47 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 49 group formation failurecycle=2
# Node 52 group formation failurecycle=2
# Node 53 group formation failurecycle=2
# Node 53 group formation failurecycle=2
# Node 53 group formation failurecycle=2
# Node 53 group formation failurecycle=2
# Node 53 group formation failurecycle=2
# Node 54 group formation failurecycle=2
# Node 54 group formation failurecycle=2
# Node 54 group formation failurecycle=2
# Node 54 group formation failurecycle=2
# Node 54 group formation failurecycle=2
# Node 54 group formation failurecycle=2
# Node 55 group formation failurecycle=2
# Node 55 group formation failurecycle=2
# Node 55 group formation failurecycle=2
# Node 56 group formation failurecycle=2
# Node 56 group formation failurecycle=2
# Node 57 group formation failurecycle=2
# Node 57 group formation failurecycle=2
# Node 59 group formation failurecycle=2
# Node 59 group formation failurecycle=2
# Node 59 group formation failurecycle=2
# Node 62 group formation failurecycle=2
# Node 62 group formation failurecycle=2
# Node 64 group formation failurecycle=2
# Node 64 group formation failurecycle=2
# Node 64 group formation failurecycle=2
# Node 66 group formation failurecycle=2
# Node 66 group formation failurecycle=2
# Node 67 group formation failurecycle=2
# Node 69 group formation failurecycle=2
# Node 70 group formation failurecycle=2
# Node 70 group formation failurecycle=2
# Node 75 group formation failurecycle=2
# Node 75 group formation failurecycle=2
# Node 78 group formation failurecycle=2
# Node 78 group formation failurecycle=2
# Node 78 group formation failurecycle=2
# Node 79 group formation failurecycle=2
# Node 81 group formation failurecycle=2
# Node 81 group formation failurecycle=2
# Node 84 group formation failurecycle=2
# Node 85 group formation failurecycle=2
# Node 86 group formation failurecycle=2
# Node 86 group formation failurecycle=2
# Node 88 group formation failurecycle=2
# Node 88 group formation failurecycle=2
# Node 88 group formation failurecycle=2
# Node 88 group formation failurecycle=2
# Node 89 group formation failurecycle=2
# Node 91 group formation failurecycle=2
# Node 91 group formation failurecycle=2
# Node 91 group formation failurecycle=2
# Node 92 group formation failurecycle=2
# Node 92 group formation failurecycle=2
# Node 92 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 94 group formation failurecycle=2
# Node 95 group formation failurecycle=2
# Node 95 group formation failurecycle=2
# Node 96 group formation failurecycle=2
# Node 97 group formation failurecycle=2
# Node 1 group formation failurecycle=3
# Node 1 group formation failurecycle=3
# Node 1 group formation failurecycle=3
# Node 3 group formation failurecycle=3
# Node 3 group formation failurecycle=3
# Node 4 group formation failurecycle=3
# Node 4 group formation failurecycle=3
# Node 6 group formation failurecycle=3
# Node 8 group formation failurecycle=3
# Node 8 group formation failurecycle=3
# Node 10 group formation failurecycle=3
# Node 12 group formation failurecycle=3
# Node 15 group formation failurecycle=3
# Node 16 group formation failurecycle=3
# Node 16 group formation failurecycle=3
# Node 16 group formation failurecycle=3
# Node 20 group formation failurecycle=3
# Node 20 group formation failurecycle=3
# Node 21 group formation failurecycle=3
# Node 22 group formation failurecycle=3
# Node 24 group formation failurecycle=3
# Node 26 group formation failurecycle=3
# Node 27 group formation failurecycle=3
# Node 30 group formation failurecycle=3
# Node 30 group formation failurecycle=3
# Node 30 group formation failurecycle=3
# Node 30 group formation failurecycle=3
# Node 31 group formation failurecycle=3
# Node 33 group formation failurecycle=3
# Node 35 group formation failurecycle=3
# Node 35 group formation failurecycle=3
# Node 37 group formation failurecycle=3
# Node 37 group formation failurecycle=3
# Node 39 group formation failurecycle=3
# Node 39 group formation failurecycle=3
# Node 40 group formation failurecycle=3
# Node 40 group formation failurecycle=3
# Node 42 group formation failurecycle=3
# Node 42 group formation failurecycle=3
# Node 42 group formation failurecycle=3
# Node 44 group formation failurecycle=3
# Node 44 group formation failurecycle=3
# Node 46 group formation failurecycle=3
# Node 46 group formation failurecycle=3
# Node 50 group formation failurecycle=3
# Node 50 group formation failurecycle=3
# Node 51 group formation failurecycle=3
# Node 52 group formation failurecycle=3
# Node 52 group formation failurecycle=3
# Node 52 group formation failurecycle=3
# Node 53 group formation failurecycle=3
# Node 53 group formation failurecycle=3
# Node 54 group formation failurecycle=3
# Node 55 group formation failurecycle=3
# Node 55 group formation failurecycle=3
# Node 57 group formation failurecycle=3
# Node 60 group formation failurecycle=3
# Node 66 group formation failurecycle=3
# Node 67 group formation failurecycle=3
# Node 67 group formation failurecycle=3
# Node 67 group formation failurecycle=3
# Node 68 group formation failurecycle=3
# Node 69 group formation failurecycle=3
# Node 69 group formation failurecycle=3
# Node 69 group formation failurecycle=3
# Node 71 group formation failurecycle=3
# Node 71 group formation failurecycle=3
# Node 72 group formation failurecycle=3
# Node 72 group formation failurecycle=3
# Node 73 group formation failurecycle=3
# Node 74 group formation failurecycle=3
# Node 76 group formation failurecycle=3
# Node 76 group formation failurecycle=3
# Node 78 group formation failurecycle=3
# Node 78 group formation failurecycle=3
# Node 82 group formation failurecycle=3
# Node 82 group formation failurecycle=3
# Node 83 group formation failurecycle=3
# Node 83 group formation failurecycle=3
# Node 83 group formation failurecycle=3
# Node 84 group formation failurecycle=3
# Node 87 group formation failurecycle=3
# Node 88 group formation failurecycle=3
# Node 89 group formation failurecycle=3
# Node 90 group formation failurecycle=3
# Node 90 group formation failurecycle=3
# Node 90 group formation failurecycle=3
# Node 90 group formation failurecycle=3
# Node 92 group formation failurecycle=3
# Node 93 group formation failurecycle=3
# Node 94 group formation failurecycle=3
# Node 95 group formation failurecycle=3
# Node 99 group formation failurecycle=3
# Node 1 group formation failurecycle=4
# Node 1 group formation failurecycle=4
# Node 1 group formation failurecycle=4
# Node 4 group formation failurecycle=4
# Node 5 group formation failurecycle=4
# Node 6 group formation failurecycle=4
# Node 6 group formation failurecycle=4
# Node 12 group formation failurecycle=4
# Node 12 group formation failurecycle=4
# Node 12 group formation failurecycle=4
# Node 12 group formation failurecycle=4
# Node 12 group formation failurecycle=4
# Node 12 group formation failurecycle=4
# Node 16 group formation failurecycle=4
# Node 16 group formation failurecycle=4
# Node 17 group formation failurecycle=4
# Node 19 group formation failurecycle=4
# Node 20 group formation failurecycle=4
# Node 20 group formation failurecycle=4
# Node 20 group formation failurecycle=4
# Node 20 group formation failurecycle=4
# Node 24 group formation failurecycle=4
# Node 26 group formation failurecycle=4
# Node 28 group formation failurecycle=4
# Node 30 group formation failurecycle=4
# Node 31 group formation failurecycle=4
# Node 33 group formation failurecycle=4
# Node 35 group formation failurecycle=4
# Node 35 group formation failurecycle=4
# Node 35 group formation failurecycle=4
# Node 36 group formation failurecycle=4
# Node 36 group formation failurecycle=4
# Node 37 group formation failurecycle=4
# Node 37 group formation failurecycle=4
# Node 37 group formation failurecycle=4
# Node 39 group formation failurecycle=4
# Node 40 group formation failurecycle=4
# Node 40 group formation failurecycle=4
# Node 40 group formation failurecycle=4
# Node 41 group formation failurecycle=4
# Node 41 group formation failurecycle=4
# Node 45 group formation failurecycle=4
# Node 45 group formation failurecycle=4
# Node 46 group formation failurecycle=4
# Node 49 group formation failurecycle=4
# Node 49 group formation failurecycle=4
# Node 49 group formation failurecycle=4
# Node 49 group formation failurecycle=4
# Node 49 group formation failurecycle=4
# Node 52 group formation failurecycle=4
# Node 58 group formation failurecycle=4
# Node 58 group formation failurecycle=4
# Node 58 group formation failurecycle=4
# Node 59 group formation failurecycle=4
# Node 59 group formation failurecycle=4
# Node 59 group formation failurecycle=4
# Node 60 group formation failurecycle=4
# Node 63 group formation failurecycle=4
# Node 68 group formation failurecycle=4
# Node 71 group formation failurecycle=4
# Node 71 group formation failurecycle=4
# Node 72 group formation failurecycle=4
# Node 72 group formation failurecycle=4
# Node 72 group formation failurecycle=4
# Node 72 group formation failurecycle=4
# Node 73 group formation failurecycle=4
# Node 73 group formation failurecycle=4
# Node 74 group formation failurecycle=4
# Node 74 group formation failurecycle=4
# Node 75 group formation failurecycle=4
# Node 75 group formation failurecycle=4
# Node 75 group formation failurecycle=4
# Node 75 group formation failurecycle=4
# Node 76 group formation failurecycle=4
# Node 81 group formation failurecycle=4
# Node 82 group formation failurecycle=4
# Node 84 group formation failurecycle=4
# Node 84 group formation failurecycle=4
# Node 84 group formation failurecycle=4
# Node 84 group formation failurecycle=4
# Node 85 group formation failurecycle=4
# Node 87 group formation failurecycle=4
# Node 87 group formation failurecycle=4
# Node 87 group formation failurecycle=4
# Node 87 group formation failurecycle=4
# Node 87 group formation failurecycle=4
# Node 87 group formation failurecycle=4
# Node 89 group formation failurecycle=4
# Node 89 group formation failurecycle=4
# Node 90 group formation failurecycle=4
# Node 92 group formation failurecycle=4
# Node 94 group formation failurecycle=4
# Node 95 group formation failurecycle=4
# Node 95 group formation failurecycle=4
# Node 96 group formation failurecycle=4
# Node 97 group formation failurecycle=4
# Node 99 group formation failurecycle=4
# Node 99 group formation failurecycle=4
# Node 1 group formation failurecycle=5
# Node 2 group formation failurecycle=5
# Node 3 group formation failurecycle=5
# Node 3 group formation failurecycle=5
# Node 4 group formation failurecycle=5
# Node 4 group formation failurecycle=5
# Node 6 group formation failurecycle=5
# Node 8 group formation failurecycle=5
# Node 9 group formation failurecycle=5
# Node 10 group formation failurecycle=5
# Node 10 group formation failurecycle=5
# Node 13 group formation failurecycle=5
# Node 14 group formation failurecycle=5
# Node 14 group formation failurecycle=5
# Node 18 group formation failurecycle=5
# Node 20 group formation failurecycle=5
# Node 21 group formation failurecycle=5
# Node 21 group formation failurecycle=5
# Node 21 group formation failurecycle=5
# Node 23 group formation failurecycle=5
# Node 23 group formation failurecycle=5
# Node 23 group formation failurecycle=5
# Node 23 group formation failurecycle=5
# Node 24 group formation failurecycle=5
# Node 24 group formation failurecycle=5
# Node 24 group formation failurecycle=5
# Node 24 group formation failurecycle=5
# Node 24 group formation failurecycle=5
# Node 25 group formation failurecycle=5
# Node 26 group formation failurecycle=5
# Node 28 group formation failurecycle=5
# Node 32 group formation failurecycle=5
# Node 32 group formation failurecycle=5
# Node 32 group formation failurecycle=5
# Node 33 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 34 group formation failurecycle=5
# Node 35 group formation failurecycle=5
# Node 36 group formation failurecycle=5
# Node 39 group formation failurecycle=5
# Node 40 group formation failurecycle=5
# Node 41 group formation failurecycle=5
# Node 41 group formation failurecycle=5
# Node 44 group formation failurecycle=5
# Node 45 group formation failurecycle=5
# Node 46 group formation failurecycle=5
# Node 47 group formation failurecycle=5
# Node 50 group formation failurecycle=5
# Node 51 group formation failurecycle=5
# Node 51 group formation failurecycle=5
# Node 51 group formation failurecycle=5
# Node 52 group formation failurecycle=5
# Node 53 group formation failurecycle=5
# Node 55 group formation failurecycle=5
# Node 57 group formation failurecycle=5
# Node 57 group formation failurecycle=5
# Node 57 group formation failurecycle=5
# Node 59 group formation failurecycle=5
# Node 59 group formation failurecycle=5
# Node 60 group formation failurecycle=5
# Node 60 group formation failurecycle=5
# Node 62 group formation failurecycle=5
# Node 66 group formation failurecycle=5
# Node 68 group formation failurecycle=5
# Node 68 group formation failurecycle=5
# Node 70 group formation failurecycle=5
# Node 73 group formation failurecycle=5
# Node 74 group formation failurecycle=5
# Node 77 group formation failurecycle=5
# Node 81 group formation failurecycle=5
# Node 81 group formation failurecycle=5
# Node 81 group formation failurecycle=5
# Node 84 group formation failurecycle=5
# Node 85 group formation failurecycle=5
# Node 86 group formation failurecycle=5
# Node 86 group formation failurecycle=5
# Node 87 group formation failurecycle=5
# Node 91 group formation failurecycle=5
# Node 94 group formation failurecycle=5
# Node 94 group formation failurecycle=5
# Node 94 group formation failurecycle=5
# Node 95 group formation failurecycle=5
# Node 95 group formation failurecycle=5
# Node 95 group formation failurecycle=5
# Node 95 group formation failurecycle=5
# Node 96 group formation failurecycle=5
# Node 96 group formation failurecycle=5
# Node 98 group formation failurecycle=5
# Node 99 group formation failurecycle=5
# Node 99 group formation failurecycle=5
# xxxxxxxxxxxxxxxxxxxx
#  final node states
# Node 0, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.767747533213399, Total relay watch time = 2.644729439234789, Node Status = online
# Node 1, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.7924327985239343, Total relay watch time = 3.995859229157433, Node Status = online
# Node 2, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.3397092252274705, Total relay watch time = 4.068062110692014, Node Status = online
# Node 3, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.261120270704755, Total relay watch time = 2.6036234754463536, Node Status = online
# Node 4, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.259265795803571, Total relay watch time = 3.1544048748762386, Node Status = online
# Node 5, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.207360521810882, Total relay watch time = 3.2131709827144306, Node Status = online
# Node 6, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.5062491039002217, Total relay watch time = 2.73239859045045, Node Status = online
# Node 7, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.8731506417506094, Total relay watch time = 4.0530422392239505, Node Status = online
# Node 8, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.914416651981888, Total relay watch time = 2.4048284258808055, Node Status = online
# Node 9, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.7995689867082745, Total relay watch time = 2.718505373762708, Node Status = online
# Node 10, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.448505265116414, Total relay watch time = 3.4069735787722615, Node Status = online
# Node 11, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.954697642097548, Total relay watch time = 3.3906965749933287, Node Status = online
# Node 12, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.8501915785112253, Total relay watch time = 3.0731251821877077, Node Status = online
# Node 13, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.74657046140199, Total relay watch time = 2.6210915106239425, Node Status = online
# Node 14, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.2252937682894314, Total relay watch time = 3.3009345395219705, Node Status = online
# Node 15, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.23152708202212, Total relay watch time = 2.1496270212137407, Node Status = online
# Node 16, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.2462097159989014, Total relay watch time = 4.300704375342489, Node Status = online
# Node 17, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.2181861256712705, Total relay watch time = 4.732222256449347, Node Status = online
# Node 18, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.618832866955112, Total relay watch time = 2.7437689734387436, Node Status = online
# Node 19, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.344989195559979, Total relay watch time = 1.0830881811886175, Node Status = online
# Node 20, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.216213948439983, Total relay watch time = 2.6822886057577895, Node Status = online
# Node 21, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.558181488669322, Total relay watch time = 2.629245781465484, Node Status = online
# Node 22, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.5206589044232723, Total relay watch time = 4.709484704389537, Node Status = online
# Node 23, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.1455199060370123, Total relay watch time = 1.8245952590970949, Node Status = online
# Node 24, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.865261654500173, Total relay watch time = 4.1768754497369045, Node Status = online
# Node 25, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.0081759008457984, Total relay watch time = 2.7754748435429275, Node Status = online
# Node 26, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.0933301721877955, Total relay watch time = 2.261781826247127, Node Status = online
# Node 27, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.817164619673798, Total relay watch time = 2.537578369667095, Node Status = online
# Node 28, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.782931365888888, Total relay watch time = 3.0416340143485874, Node Status = online
# Node 29, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.566924297853314, Total relay watch time = 1.8425737842945344, Node Status = online
# Node 30, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.8027634021767205, Total relay watch time = 1.5633132159192566, Node Status = online
# Node 31, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.1207373779724683, Total relay watch time = 3.070161846239003, Node Status = online
# Node 32, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.864544756437992, Total relay watch time = 4.295528119469434, Node Status = online
# Node 33, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.1090746547308044, Total relay watch time = 0.9251206944768118, Node Status = online
# Node 34, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.844269208009436, Total relay watch time = 1.6743652122925397, Node Status = online
# Node 35, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.92875284436586, Total relay watch time = 3.219057731263089, Node Status = online
# Node 36, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.040943698535136, Total relay watch time = 3.9256821847682746, Node Status = online
# Node 37, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.2397613262992704, Total relay watch time = 3.053715666132764, Node Status = online
# Node 38, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.4449366646952946, Total relay watch time = 2.9979387745773813, Node Status = online
# Node 39, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.619441387781981, Total relay watch time = 2.8884296084842784, Node Status = online
# Node 40, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.62984943915799, Total relay watch time = 2.3221953366658643, Node Status = online
# Node 41, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.5636013417893633, Total relay watch time = 2.473129957896026, Node Status = online
# Node 42, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.8866758384323026, Total relay watch time = 2.652239482986056, Node Status = online
# Node 43, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.3944706896961785, Total relay watch time = 3.857901534129995, Node Status = online
# Node 44, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.4339776666661277, Total relay watch time = 2.8629424960942313, Node Status = online
# Node 45, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.6551827452464996, Total relay watch time = 3.611009200450359, Node Status = online
# Node 46, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.9026662204782514, Total relay watch time = 3.0691864050391273, Node Status = online
# Node 47, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.389718960129714, Total relay watch time = 1.4095809859588755, Node Status = online
# Node 48, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.1187246775005386, Total relay watch time = 2.359800046098872, Node Status = online
# Node 49, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.413566026345368, Total relay watch time = 2.8669687627614993, Node Status = online
# Node 50, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.9292296627122956, Total relay watch time = 3.1925504212578235, Node Status = online
# Node 51, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.075031305670931, Total relay watch time = 1.515395174978847, Node Status = online
# Node 52, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.1913985980539974, Total relay watch time = 4.126520694622587, Node Status = online
# Node 53, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.440994335823559, Total relay watch time = 2.6358309569960987, Node Status = online
# Node 54, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.749808916350652, Total relay watch time = 3.4102332473654453, Node Status = online
# Node 55, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.29238907469048, Total relay watch time = 2.6046601511840453, Node Status = online
# Node 56, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.463000375040982, Total relay watch time = 2.740625869884995, Node Status = online
# Node 57, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.337910588057536, Total relay watch time = 3.2691183781122195, Node Status = online
# Node 58, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.469475776907701, Total relay watch time = 3.0154327126095892, Node Status = online
# Node 59, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.301550043804475, Total relay watch time = 3.7805200412258406, Node Status = online
# Node 60, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.86680295682607, Total relay watch time = 2.784803436329418, Node Status = online
# Node 61, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.461727720530263, Total relay watch time = 4.221417087797191, Node Status = online
# Node 62, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.233521479013223, Total relay watch time = 1.3254338186755072, Node Status = online
# Node 63, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.9470937606791927, Total relay watch time = 1.7229969604038018, Node Status = online
# Node 64, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.6580033592639385, Total relay watch time = 4.775404278661168, Node Status = online
# Node 65, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.2246075437546398, Total relay watch time = 2.8470693499550377, Node Status = online
# Node 66, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.806062318620321, Total relay watch time = 2.2735649036769607, Node Status = online
# Node 67, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.086850778590126, Total relay watch time = 3.952938826537406, Node Status = online
# Node 68, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.844564399172354, Total relay watch time = 1.9359885780145876, Node Status = online
# Node 69, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.546709733575538, Total relay watch time = 1.5411558014980424, Node Status = online
# Node 70, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.428401792702434, Total relay watch time = 3.9862876477319165, Node Status = online
# Node 71, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.422731450494334, Total relay watch time = 1.9994214038821836, Node Status = online
# Node 72, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.1760967239119626, Total relay watch time = 1.1233568627351822, Node Status = online
# Node 73, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.468495857430123, Total relay watch time = 3.4931630175598314, Node Status = online
# Node 74, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.0490363460173304, Total relay watch time = 3.052782552641945, Node Status = online
# Node 75, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.094171269224073, Total relay watch time = 2.048226933149596, Node Status = online
# Node 76, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.8474284004386612, Total relay watch time = 5.425495235523428, Node Status = online
# Node 77, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.075851204995195, Total relay watch time = 1.750927656840995, Node Status = online
# Node 78, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.7399365481119131, Total relay watch time = 4.233325175107467, Node Status = online
# Node 79, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.111416086485476, Total relay watch time = 1.557501629279881, Node Status = online
# Node 80, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.9771555687590292, Total relay watch time = 0.8308624386455503, Node Status = online
# Node 81, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.5142215902802545, Total relay watch time = 3.7305870198274693, Node Status = online
# Node 82, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.553092937829672, Total relay watch time = 2.3114142223275813, Node Status = online
# Node 83, # of Entries = 6, # Groups Joined = 6, Total relay request time = 1.9184082225618717, Total relay watch time = 2.8029127551442476, Node Status = online
# Node 84, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.4370000648881676, Total relay watch time = 2.7781292561577255, Node Status = online
# Node 85, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.090074598324641, Total relay watch time = 0.7788457653227376, Node Status = online
# Node 86, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.9876605352286147, Total relay watch time = 4.537666642013469, Node Status = online
# Node 87, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.760526274852664, Total relay watch time = 0.9436361076529733, Node Status = online
# Node 88, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.9110829927598423, Total relay watch time = 2.645954619470043, Node Status = online
# Node 89, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.568115259095982, Total relay watch time = 2.342413914642741, Node Status = online
# Node 90, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.586750980664543, Total relay watch time = 2.6071817643909383, Node Status = online
# Node 91, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.1522035307190173, Total relay watch time = 3.0121496299902346, Node Status = online
# Node 92, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.448620825205166, Total relay watch time = 3.315133986708074, Node Status = online
# Node 93, # of Entries = 6, # Groups Joined = 6, Total relay request time = 4.602070735855679, Total relay watch time = 4.141447183584059, Node Status = online
# Node 94, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.868562803742916, Total relay watch time = 2.686534386419699, Node Status = online
# Node 95, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.412057639617715, Total relay watch time = 3.7844569418898018, Node Status = online
# Node 96, # of Entries = 6, # Groups Joined = 6, Total relay request time = 2.369970772849017, Total relay watch time = 3.5712926666933025, Node Status = online
# Node 97, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.146228004843143, Total relay watch time = 3.792005467004224, Node Status = online
# Node 98, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.206974996611988, Total relay watch time = 3.5168307514181865, Node Status = online
# Node 99, # of Entries = 6, # Groups Joined = 6, Total relay request time = 3.870909381748592, Total relay watch time = 3.1090460000987004, Node Status = online
